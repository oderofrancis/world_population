# %% [markdown]
# <a href="https://colab.research.google.com/github/oderofrancis/world_population/blob/main/parsehub_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

import pandas as pd

from pandas import json_normalize

# %%
params = {
  "api_key": "tVOy10nCKRyQ",
  "format": "json"
}
r = requests.get('https://parsehub.com/api/v2/projects/tO9u2DxohXth/last_ready_run/data', params=params)

# %%
response = r.json()

response = json_normalize(response['country'])

# %%
response = pd.DataFrame(response)

# %%
response.head()
# Out:
#             name                                                url  \
# 0          China  https://www.worldometers.info/world-population...
# 1          India  https://www.worldometers.info/world-population...
# 2  United States  https://www.worldometers.info/world-population...
# 3      Indonesia  https://www.worldometers.info/world-population...
# 4       Pakistan  https://www.worldometers.info/world-population...
#
#       population yearly_change  net_change density_p_perkm2   lad_area  \
# 0  1,439,323,776        0.39 %   5,540,090              153  9,388,211
# 1  1,380,004,385        0.99 %  13,586,631              464  2,973,190
# 2    331,002,651        0.59 %   1,937,734               36  9,147,420
# 3    273,523,615        1.07 %   2,898,047              151  1,811,570
# 4    220,892,340        2.00 %   4,327,022              287    770,880
#
#    migrants tertility_rate medium_age urban_pop world_share
# 0  -348,399            1.7         38      61 %     18.47 %
# 1  -532,687            2.2         28      35 %     17.70 %
# 2   954,806            1.8         38      83 %      4.25 %
# 3   -98,955            2.3         30      56 %      3.51 %
# 4  -233,379            3.6         23      35 %      2.83 %
