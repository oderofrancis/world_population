# %% [markdown]
# <a href="https://colab.research.google.com/github/oderofrancis/world_population/blob/main/parsehub_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

params = {
  "api_key": "tVOy10nCKRyQ",
  "format": "csv"
}
r = requests.get('https://parsehub.com/api/v2/projects/tO9u2DxohXth/last_ready_run/data', params=params)

# %%
response = r.text

print(response)
# Out:
# "country_name","country_url","country_population","country_yearly_change","country_net_change","country_density_p_perkm2","country_lad_area","country_migrants","country_tertility_rate","country_medium_age","country_urban_pop","country_world_share"
# "China","https://www.worldometers.info/world-population/china-population/","1,439,323,776","0.39 %","5,540,090","153","9,388,211","-348,399","1.7","38","61 %","18.47 %"
# "India","https://www.worldometers.info/world-population/india-population/","1,380,004,385","0.99 %","13,586,631","464","2,973,190","-532,687","2.2","28","35 %","17.70 %"
# "United States","https://www.worldometers.info/world-population/us-population/","331,002,651","0.59 %","1,937,734","36","9,147,420","954,806","1.8","38","83 %","4.25 %"
# "Indonesia","https://www.worldometers.info/world-population/indonesia-population/","273,523,615","1.07 %","2,898,047","151","1,811,570","-98,955","2.3","30","56 %","3.51 %"
# ...
