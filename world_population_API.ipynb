# %% [markdown]
# <a href="https://colab.research.google.com/github/oderofrancis/world_population/blob/main/world_population_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = 'https://parsehub.com/api/v2/runs/tUXRXh6KYxPH/data'

params = {
  "api_key": "tVOy10nCKRyQ",
  "format": "json"
}

# %%
r = requests.get(url, params=params)

# %%
# print(r.text)

# %%
world_pop = r.json()

# %%
world_pop
# Out:
# {'country': [{'name': 'China',
#    'url': 'https://www.worldometers.info/world-population/china-population/',
#    'population': '1,439,323,776',
#    'yearly_change': '0.39 %',
#    'net_change': '5,540,090',
#    'density_p_perkm2': '153',
#    'lad_area': '9,388,211',
#    'migrants': '-348,399',
#    'tertility_rate': '1.7',
#    'medium_age': '38',
#    'urban_pop': '61 %',
#    'world_share': '18.47 %'},
#   {'name': 'India',
#    'url': 'https://www.worldometers.info/world-population/india-population/',
#    'population': '1,380,004,385',
#    'yearly_change': '0.99 %',
#    'net_change': '13,586,631',
#    'density_p_perkm2': '464',
#    'lad_area': '2,973,190',
#    'migrants': '-532,687',
#    'tertility_rate': '2.2',
#    'medium_age': '28',
#    'urban_pop': '35 %',
#    'world_share': '17.70 %'},
#   {'name': 'United States',
#    'url': 'https://www.worldometers.info/world-population/us-population/',
#    'population': '331,002,651',
#    'yearly_change': '0.59 %',
# ...
